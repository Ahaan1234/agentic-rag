# %%
from smolagents import LiteLLMModel, ToolCallingAgent
import os

model = LiteLLMModel(model_id="gemini/gemini-2.0-flash-lite", api_key=os.getenv('GEMINI_API_KEY'))

# %%
import re
import requests
from markdownify import markdownify as md
from requests.exceptions import RequestException
from smolagents import tool

@tool
def visit_webpage(url: str) -> str:
    """
    Visits a webpage at the given URL and returns its content as a markdown string.

    Args:
        url (str): The URL of the webpage to visit.

    Returns:
        str: The content of the webpage converted to markdown, or an error message if the request fails.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()

        markdown_content = md(response.text).strip()
        markdown_content = re.sub(r"\n{3,}", "\n\n", markdown_content)

        return markdown_content

    except RequestException as e:
        return f"Error fetching the webpage: {str(e)}"
    except Exception as e:
        return f"An unexpected error occurred: {str(e)}"

# %%
print(visit_webpage("https://en.wikipedia.org/wiki/Football_Manager")[:5000])
# Out:
# Football Manager - Wikipedia
#
# [Jump to content](#bodyContent)
#
# Main menu
#
# Main menu
#
# move to sidebar
# hide
#
# Navigation
#
# * [Main page](/wiki/Main_Page "Visit the main page [z]")
# * [Contents](/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
# * [Current events](/wiki/Portal:Current_events "Articles related to current events")
# * [Random article](/wiki/Special:Random "Visit a randomly selected article [x]")
# * [About Wikipedia](/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
# * [Contact us](//en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
# Contribute
#
# * [Help](/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
# * [Learn to edit](/wiki/Help:Introduction "Learn how to edit Wikipedia")
# * [Community portal](/wiki/Wikipedia:Community_portal "The hub for editors")
# * [Recent changes](/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")
# * [Upload file](/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")
# * [Special pages](/wiki/Special:SpecialPages)
#
# [![](/static/images/icons/wikipedia.png)
#
# ![Wikipedia](/static/images/mobile/copyright/wikipedia-wordmark-en.svg)
# ![The Free Encyclopedia](/static/images/mobile/copyright/wikipedia-tagline-en.svg)](/wiki/Main_Page)
#
# [Search](/wiki/Special:Search "Search Wikipedia [f]")
#
# Search
#
# Appearance
#
# * [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Football+Manager "You are encouraged to create an account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Football+Manager "You're encouraged to log in; however, it's not mandatory. [o]")
#
# Personal tools
#
# * [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Football+Manager "You are encouraged to create an account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Football+Manager "You're encouraged to log in; however, it's not mandatory. [o]")
#
# Pages for logged out editors [learn more](/wiki/Help:Introduction)
#
# * [Contributions](/wiki/Special:MyContributions "A list of edits made from this IP address [y]")
# * [Talk](/wiki/Special:MyTalk "Discussion about edits from this IP address [n]")
#
# Contents
# --------
#
# move to sidebar
# hide
#
# * [(Top)](#)
# * [1
#   Main series](#Main_series)
#
#   Toggle Main series subsection
#   + [1.1
#     *Football Manager 2005*](#Football_Manager_2005)
#   + [1.2
#     *Football Manager 2006*](#Football_Manager_2006)
#     - [1.2.1
#       *Football Manager 2006* – Xbox 360](#Football_Manager_2006_–_Xbox_360)
#   + [1.3
#     *Football Manager 2007*](#Football_Manager_2007)
#   + [1.4
#     *Football Manager 2008*](#Football_Manager_2008)
#   + [1.5
#     *Football Manager 2009*](#Football_Manager_2009)
#   + [1.6
#     *Football Manager 2010*](#Football_Manager_2010)
#   + [1.7
#     *Football Manager 2011*](#Football_Manager_2011)
#   + [1.8
#     *Football Manager 2012*](#Football_Manager_2012)
#   + [1.9
#     *Football Manager 2013*](#Football_Manager_2013)
#   + [1.10
#     *Football Manager 2014*](#Football_Manager_2014)
#   + [1.11
#     *Football Manager 2015*](#Football_Manager_2015)
#   + [1.12
#     *Football Manager 2016*](#Football_Manager_2016)
#   + [1.13
#     *Football Manager 2017*](#Football_Manager_2017)
#   + [1.14
#     *Football Manager 2018*](#Football_Manager_2018)
#   + [1.15
#     *Football Manager 2019*](#Football_Manager_2019)
#   + [1.16
#     *Football Manager 2020*](#Football_Manager_2020)
#   + [1.17
#     *Football Manager 2021*](#Football_Manager_2021)
#   + [1.18
#     *Football Manager 2022*](#Football_Manager_2022)
#   + [1.19
#     *Football Manager 2023*](#Football_Manager_2023)
#   + [1.20
#     *Football Manager 2024*](#Football_Manager_2024)
#   + [1.21
#     *Football Manager 25* (cancelled)](#Football_Manager_25_(cancelled))
# * [2
#   Other games](#Other_games)
#
#   Toggle Other games subsection
#   + [2.1
#     *Football Manager Mobile*](#Football_Manager_Mobile)
#   + [2.2
#     *Football Manager Live*](#Football_Manager_Live)
#   + [2.3
#     *Football Manager Online*](#Football_Manager_Online)
#   + [2.4
#     *Football Manager Touch*](#Football_Manager_Touch)
#   + [2.5
#     *Sonic & All-Stars Racing Transformed*](#Sonic_&_All-Stars_Racing_Transformed)
#   + [2.6
#     *Sega Football Club Champions*](#Sega_Football_Club_Champions)
# * [3
#   Influence](#Influence)
# * [4
#   *Football Manager* in academic work](#Football_Manager_in_academic_work)
# * [5
#   See also](#See_also)
# * [6
#   References](#References)
# * [7
#   External links](#External_links)
#
# Toggle the table of contents
#
# *Football Manager*
# ==================
#
# 30 languages
#
# * [العربية](https://ar.wikipedia.org/wiki/%D9%81%D9%88%D8%AA%D8%A8%D9%88%D9%84_%D9%85%D9%86%D9%8A%D8%AC%D8%B1 "فوتبول منيجر – Arabic")
# * [Български](https://bg.wikipedia.org/wiki/Football_Manag

# %%
from smolagents import ToolCallingAgent, DuckDuckGoSearchTool

web_agent = ToolCallingAgent(
    tools=[DuckDuckGoSearchTool(), visit_webpage],
    model=model
)
# Out:
# /Users/ahaanshah/Desktop/Duke/ECs/summer-25/agentic-rag/.venv/lib/python3.13/site-packages/smolagents/default_tools.py:135: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   self.ddgs = DDGS(**kwargs)

# %%
managed_web_agent = ManagedAgent(
    agent=web_agent,
    name="search_agent",
    description="Runs web searches for you. Give it your query as an argument.",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 managed_web_agent = ManagedAgent(
#       2     agent=web_agent,
#       3     name="search_agent",
#       4     description="Runs web searches for you. Give it your query as an argument.",
#       5 )
#
# NameError: name 'ManagedAgent' is not defined
